# %% [markdown]
# # Wiley Handlabeled Data Splitter
# This notebook focusses on building functions that enable the taking-in of a list or a directory of fulltext .txt files, and splitting them into individual tokens to be hand-labeled by humans, so they can be used as training data for NLP models.

# %%
demo_file = "10.1002_ange.201500925.txt"

# %%
filepath = '/Users/Jonathan/Desktop/Test_Folder/'

# %%
import nltk
from nltk import tokenize

# %%
import os
import random
import pandas as pd
from openpyxl import load_workbook

# %%
def append_df_to_excel(filename, df, sheet_name='Sheet1', startrow=0, startcol=None,
                       truncate_sheet=False,
                       **to_excel_kwargs):
    """
    Append a DataFrame [df] to existing Excel file [filename]
    into [sheet_name] Sheet.
    If [filename] doesn't exist, then this function will create it.

    Parameters:
      filename : File path or existing ExcelWriter
                 (Example: '/path/to/file.xlsx')
      df : dataframe to save to workbook
      sheet_name : Name of sheet which will contain DataFrame.
                   (default: 'Sheet1')
      startrow : upper left cell row to dump data frame.
                 Per default (startrow=None) calculate the last row
                 in the existing DF and write to the next row...

      startcol : upper left cell column to dump data frame.


      truncate_sheet : truncate (remove and recreate) [sheet_name]
                       before writing DataFrame to Excel file
      to_excel_kwargs : arguments which will be passed to `DataFrame.to_excel()`
                        [can be dictionary]

    Returns: None
    """

    print('On dataframe ', int(startcol/6)+1)
    # ignore [engine] parameter if it was passed
    if 'engine' in to_excel_kwargs:
        to_excel_kwargs.pop('engine')

    writer = pd.ExcelWriter(filename, engine='openpyxl')

    # Python 2.x: define [FileNotFoundError] exception if it doesn't exist
    try:
        FileNotFoundError
    except NameError:
        FileNotFoundError = IOError


    try:
        # try to open an existing workbook
        writer.book = load_workbook(filename)

        if startcol is None and sheet_name in writer.book.sheetnames:
            startcol = writer.book[sheet_name].max_col

        # truncate sheet
        if truncate_sheet and sheet_name in writer.book.sheetnames:
            # index of [sheet_name] sheet
            idx = writer.book.sheetnames.index(sheet_name)
            # remove [sheet_name]
            writer.book.remove(writer.book.worksheets[idx])
            # create an empty sheet [sheet_name] using old index
            writer.book.create_sheet(sheet_name, idx)

        # copy existing sheets
        writer.sheets = {ws.title:ws for ws in writer.book.worksheets}
    except FileNotFoundError:
        # file does not exist yet, we will create it
        pass


    if startcol is None:
        startcol = 0

    # write out the new sheet
    df.to_excel(writer, sheet_name, startrow=startrow, startcol=startcol, **to_excel_kwargs)

    # save the workbook
    writer.save()

# %%
directory_path = '/Users/Jonathan/Desktop/WileySynthCorpus/'
name_list = ['name', 'tokens', 'BESIO', 'entity', 'mol_class']

# %% [markdown]
# ## Note:
# I highly recommend that you use a smaller number of papers per sheet, or write a loop that makes several different spreadsheets. It seems like this gets slower and slower the more papers we add into the spreadsheet.

# %%
#Ok, that would make for a perfect text. Now we need to put that perfect text into a spreadsheet. 
#We'll then plan to generalize to multiple text files in a single directory.
# directory_path = '/Users/Jonathan/Desktop/Test_Folder/'
# name_list = ['name', 'tokens', 'BESIO', 'entity', 'mol_class']
publication_lists = os.listdir(directory_path)

#Need to long-term update this to randomly select a subset, based on how many different papers they want to 
#add, and how many papers per sheet is selected.
papers_per_sheet = 10
total_papers = 40
num_sheets = total_papers/papers_per_sheet
selected_pubs = []
filename = "Wiley_Labeling_Spreadsheet.xlsx"

#This loop randomly selects papers from our total corpus list
while total_papers > len(selected_pubs):
    random_num = random.randint(1, len(publication_lists))
    print(random_num)
    selected_pubs.append(publication_lists[random_num-1])
#print(selected_pubs)
    

#Ok, the above definitely is working totally fine. 
pubs_in_sheet = 0
total_pubs = 0
for i in selected_pubs:
    #Make it such that the sheet number we're on is always an int.
    sheet_number = int(total_pubs/papers_per_sheet)
    #Check to reset column count:
    if pubs_in_sheet%papers_per_sheet == 0:
        pubs_in_sheet = 0
    #Open the file, clean it of odd characters, then tokenize it with NLTK.
    #This will definitely fail if it tries to open the json files in this directory
    #But otherwise, it's fine. 2/25000, what're the odds?
    file = open(directory_path+str(i), mode = 'r')
    text = file.read()
    file.close()
    text = text.replace("\xad", '-')
    cleaned = text.replace("\n", " ")
    cleaned = cleaned.replace('\x0c', ' ')
    #Double space to single space
    cleaned = cleaned.replace('  ', ' ')
    #Triple space to single space
    cleaned = cleaned.replace('   ', ' ')
    #Tokenize the raw text at a word level.
    tokenized_texts = tokenize.word_tokenize(cleaned)
    
    #Build a new dataframe and place the tokens and doi into it    
    df = pd.DataFrame(columns = name_list)
    df['tokens'] = tokenized_texts
    #Add the doi, which is just the filename minus the .txt extension
    df['name'][3] = str(i[:-4])
    df['name'][4] = "Paper Count: " + str(pubs_in_sheet)
    
    append_df_to_excel(directory_path+filename, df, sheet_name = "Sheet "+str(sheet_number), startcol = 6*pubs_in_sheet)
    pubs_in_sheet += 1
    total_pubs += 1
print("Your spreadsheet is ready!")
# Out:
# 19950
# 1796
# 938
# 22363
# 21240
# 25111
# 24121
# 24854
# 18473
# 23766
# 21519
# 19901
# 14452
# 11766
# 6123
# 8938
# 10910
# 25103
# 5794
# 617
# 9627
# 21367
# 6437
# 23322
# 18118
# 13038
# 20399
# 20356
# 14337
# 4037
# 17911
# 15886
# 16551
# 17878
# 9668
# 21714
# 24524
# 1423
# 19250
# 23910
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# On dataframe  9
# On dataframe  10
# Your spreadsheet is ready!

# %%
#Check the pub.
publication_lists[19275]
# Out:
# '10.1002_jhet.5570310208.txt'

# %% [markdown]
# Now we functionalize it all:

# %%
def build_spreadsheets(filename, doc_directory_path, column_name_list, papers_per_sheet = 10, total_papers = 50):
    """"""
    
    publication_lists = os.listdir(directory_path)

    #Need to long-term update this to randomly select a subset, based on how many different papers they want to 
    #add, and how many papers per sheet is selected.
    num_sheets = total_papers/papers_per_sheet
    selected_pubs = []

    #This loop randomly selects papers from our total corpus list
    while total_papers > len(selected_pubs):
        random_num = random.randint(1, len(publication_lists))
        print("Random Publication Selected: ", (random_num-1))
        selected_pubs.append(publication_lists[random_num-1])


    #Ok, the above definitely is working totally fine. 
    pubs_in_sheet = 0
    total_pubs = 0
    for i in selected_pubs:
        #Make it such that the sheet number we're on is always an int.
        sheet_number = int(total_pubs/papers_per_sheet)
        #Check to reset column count:
        if pubs_in_sheet%papers_per_sheet == 0:
            pubs_in_sheet = 0
        #Open the file, clean it of odd characters, then tokenize it with NLTK.
        #This will definitely fail if it tries to open the json files in this directory
        #But otherwise, it's fine. 2/25000, what're the odds?
        file = open(directory_path+str(i), mode = 'r')
        text = file.read()
        file.close()
        text = text.replace("\xad", '-')
        cleaned = text.replace("\n", " ")
        cleaned = cleaned.replace('\x0c', ' ')
        #Double space to single space
        cleaned = cleaned.replace('  ', ' ')
        #Triple space to single space
        cleaned = cleaned.replace('   ', ' ')
        #Tokenize the raw text at a word level.
        tokenized_texts = tokenize.word_tokenize(cleaned)

        #Build a new dataframe and place the tokens and doi into it    
        df = pd.DataFrame(columns = name_list)
        df['tokens'] = tokenized_texts
        #Add the doi, which is just the filename minus the .txt extension
        df['name'][3] = str(i[:-4])
        df['name'][4] = "Paper Count: " + str(pubs_in_sheet)

        append_df_to_excel(directory_path+filename, df, sheet_name = "Sheet "+str(sheet_number), startcol = 6*pubs_in_sheet)
        pubs_in_sheet += 1
        total_pubs += 1
    print("Your spreadsheet is ready!")

# %%
i = 0
col_list = ['name', 'tokens', 'BESIO', 'entity', 'mol_class']
while i < 10:
    print("Wiley_Spreadsheet {}.xlsx".format(i))
    build_spreadsheets("Wiley_Spreadsheet {}.xlsx".format(str(i)), '/Users/Jonathan/Desktop/WileySynthCorpus/', col_list)
    i += 1
# Out:
# Wiley_Spreadsheet 0.xlsx
# Random Publication Selected:  7750
# Random Publication Selected:  18018
# Random Publication Selected:  24960
# Random Publication Selected:  20523
# Random Publication Selected:  7247
# Random Publication Selected:  392
# Random Publication Selected:  22032
# Random Publication Selected:  12017
# Random Publication Selected:  3112
# Random Publication Selected:  22024
# Random Publication Selected:  2819
# Random Publication Selected:  4968
# Random Publication Selected:  18232
# Random Publication Selected:  5188
# Random Publication Selected:  13589
# Random Publication Selected:  2585
# Random Publication Selected:  18563
# Random Publication Selected:  3483
# Random Publication Selected:  22227
# Random Publication Selected:  403
# Random Publication Selected:  21197
# Random Publication Selected:  8014
# Random Publication Selected:  6194
# Random Publication Selected:  8333
# Random Publication Selected:  3047
# Random Publication Selected:  19015
# Random Publication Selected:  10864
# Random Publication Selected:  18763
# Random Publication Selected:  23056
# Random Publication Selected:  8131
# Random Publication Selected:  20992
# Random Publication Selected:  22832
# Random Publication Selected:  13554
# Random Publication Selected:  21562
# Random Publication Selected:  12122
# Random Publication Selected:  11049
# Random Publication Selected:  9952
# Random Publication Selected:  6360
# Random Publication Selected:  11612
# Random Publication Selected:  22753
# Random Publication Selected:  9420
# Random Publication Selected:  12380
# Random Publication Selected:  14142
# Random Publication Selected:  2618
# Random Publication Selected:  20775
# Random Publication Selected:  7469
# Random Publication Selected:  15973
# Random Publication Selected:  23506
# Random Publication Selected:  9838
# Random Publication Selected:  9795
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# C:\Users\Jonathan\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# Your spreadsheet is ready!
# Wiley_Spreadsheet 1.xlsx
# Random Publication Selected:  7323
# Random Publication Selected:  15433
# Random Publication Selected:  20127
# Random Publication Selected:  9056
# Random Publication Selected:  16153
# Random Publication Selected:  4019
# Random Publication Selected:  18182
# Random Publication Selected:  16414
# Random Publication Selected:  8577
# Random Publication Selected:  24953
# Random Publication Selected:  13121
# Random Publication Selected:  17036
# Random Publication Selected:  12404
# Random Publication Selected:  16297
# Random Publication Selected:  25173
# Random Publication Selected:  11841
# Random Publication Selected:  5732
# Random Publication Selected:  7154
# Random Publication Selected:  3939
# Random Publication Selected:  14095
# Random Publication Selected:  800
# Random Publication Selected:  12195
# Random Publication Selected:  10205
# Random Publication Selected:  2467
# Random Publication Selected:  8846
# Random Publication Selected:  11513
# Random Publication Selected:  21524
# Random Publication Selected:  6350
# Random Publication Selected:  8446
# Random Publication Selected:  18264
# Random Publication Selected:  6494
# Random Publication Selected:  2730
# Random Publication Selected:  21531
# Random Publication Selected:  14554
# Random Publication Selected:  20026
# Random Publication Selected:  24237
# Random Publication Selected:  22102
# Random Publication Selected:  11273
# Random Publication Selected:  23383
# Random Publication Selected:  12018
# Random Publication Selected:  9875
# Random Publication Selected:  1391
# Random Publication Selected:  24940
# Random Publication Selected:  11029
# Random Publication Selected:  3695
# Random Publication Selected:  3859
# Random Publication Selected:  24518
# Random Publication Selected:  15456
# Random Publication Selected:  14233
# Random Publication Selected:  9948
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# Your spreadsheet is ready!
# Wiley_Spreadsheet 2.xlsx
# Random Publication Selected:  11659
# Random Publication Selected:  4210
# Random Publication Selected:  21957
# Random Publication Selected:  9734
# Random Publication Selected:  8248
# Random Publication Selected:  3567
# Random Publication Selected:  15541
# Random Publication Selected:  10846
# Random Publication Selected:  14340
# Random Publication Selected:  5013
# Random Publication Selected:  250
# Random Publication Selected:  10398
# Random Publication Selected:  20148
# Random Publication Selected:  23596
# Random Publication Selected:  6095
# Random Publication Selected:  4533
# Random Publication Selected:  4994
# Random Publication Selected:  15611
# Random Publication Selected:  7587
# Random Publication Selected:  24613
# Random Publication Selected:  2916
# Random Publication Selected:  14762
# Random Publication Selected:  45
# Random Publication Selected:  19108
# Random Publication Selected:  1091
# Random Publication Selected:  18750
# Random Publication Selected:  2870
# Random Publication Selected:  16629
# Random Publication Selected:  13125
# Random Publication Selected:  21798
# Random Publication Selected:  8881
# Random Publication Selected:  21434
# Random Publication Selected:  24775
# Random Publication Selected:  13293
# Random Publication Selected:  8218
# Random Publication Selected:  16645
# Random Publication Selected:  23291
# Random Publication Selected:  3954
# Random Publication Selected:  19661
# Random Publication Selected:  22674
# Random Publication Selected:  23178
# Random Publication Selected:  14443
# Random Publication Selected:  6951
# Random Publication Selected:  6773
# Random Publication Selected:  11903
# Random Publication Selected:  8658
# Random Publication Selected:  13423
# Random Publication Selected:  3133
# Random Publication Selected:  19406
# Random Publication Selected:  15322
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# Your spreadsheet is ready!
# Wiley_Spreadsheet 3.xlsx
# Random Publication Selected:  15381
# Random Publication Selected:  5221
# Random Publication Selected:  1144
# Random Publication Selected:  9770
# Random Publication Selected:  5411
# Random Publication Selected:  9925
# Random Publication Selected:  14915
# Random Publication Selected:  8193
# Random Publication Selected:  6423
# Random Publication Selected:  11594
# Random Publication Selected:  20766
# Random Publication Selected:  6641
# Random Publication Selected:  8716
# Random Publication Selected:  4880
# Random Publication Selected:  2808
# Random Publication Selected:  16943
# Random Publication Selected:  21130
# Random Publication Selected:  20607
# Random Publication Selected:  21867
# Random Publication Selected:  14983
# Random Publication Selected:  1182
# Random Publication Selected:  17285
# Random Publication Selected:  22493
# Random Publication Selected:  470
# Random Publication Selected:  18484
# Random Publication Selected:  14711
# Random Publication Selected:  11579
# Random Publication Selected:  2452
# Random Publication Selected:  11784
# Random Publication Selected:  12254
# Random Publication Selected:  669
# Random Publication Selected:  17204
# Random Publication Selected:  25171
# Random Publication Selected:  9795
# Random Publication Selected:  13584
# Random Publication Selected:  13861
# Random Publication Selected:  9732
# Random Publication Selected:  15440
# Random Publication Selected:  21697
# Random Publication Selected:  12479
# Random Publication Selected:  22252
# Random Publication Selected:  10735
# Random Publication Selected:  10807
# Random Publication Selected:  11031
# Random Publication Selected:  1842
# Random Publication Selected:  19150
# Random Publication Selected:  12069
# Random Publication Selected:  1669
# Random Publication Selected:  17582
# Random Publication Selected:  12333
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# Your spreadsheet is ready!
# Wiley_Spreadsheet 4.xlsx
# Random Publication Selected:  5661
# Random Publication Selected:  3293
# Random Publication Selected:  20303
# Random Publication Selected:  770
# Random Publication Selected:  13157
# Random Publication Selected:  3503
# Random Publication Selected:  4270
# Random Publication Selected:  9642
# Random Publication Selected:  13097
# Random Publication Selected:  13804
# Random Publication Selected:  19238
# Random Publication Selected:  3921
# Random Publication Selected:  10602
# Random Publication Selected:  12274
# Random Publication Selected:  16533
# Random Publication Selected:  9063
# Random Publication Selected:  24022
# Random Publication Selected:  20353
# Random Publication Selected:  18545
# Random Publication Selected:  9757
# Random Publication Selected:  16318
# Random Publication Selected:  18053
# Random Publication Selected:  16463
# Random Publication Selected:  6989
# Random Publication Selected:  7683
# Random Publication Selected:  4049
# Random Publication Selected:  16643
# Random Publication Selected:  1539
# Random Publication Selected:  630
# Random Publication Selected:  23374
# Random Publication Selected:  22741
# Random Publication Selected:  22542
# Random Publication Selected:  10515
# Random Publication Selected:  20265
# Random Publication Selected:  5114
# Random Publication Selected:  5538
# Random Publication Selected:  17123
# Random Publication Selected:  17441
# Random Publication Selected:  11184
# Random Publication Selected:  16567
# Random Publication Selected:  21564
# Random Publication Selected:  11878
# Random Publication Selected:  10670
# Random Publication Selected:  13850
# Random Publication Selected:  1346
# Random Publication Selected:  5490
# Random Publication Selected:  16538
# Random Publication Selected:  10505
# Random Publication Selected:  17639
# Random Publication Selected:  10952
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# Your spreadsheet is ready!
# Wiley_Spreadsheet 5.xlsx
# Random Publication Selected:  12053
# Random Publication Selected:  4653
# Random Publication Selected:  19213
# Random Publication Selected:  15010
# Random Publication Selected:  7822
# Random Publication Selected:  12012
# Random Publication Selected:  10754
# Random Publication Selected:  9571
# Random Publication Selected:  5544
# Random Publication Selected:  1917
# Random Publication Selected:  16779
# Random Publication Selected:  4033
# Random Publication Selected:  11814
# Random Publication Selected:  17714
# Random Publication Selected:  18732
# Random Publication Selected:  21974
# Random Publication Selected:  18200
# Random Publication Selected:  25011
# Random Publication Selected:  4665
# Random Publication Selected:  2651
# Random Publication Selected:  21534
# Random Publication Selected:  5601
# Random Publication Selected:  23289
# Random Publication Selected:  13485
# Random Publication Selected:  19522
# Random Publication Selected:  11584
# Random Publication Selected:  10573
# Random Publication Selected:  10784
# Random Publication Selected:  7388
# Random Publication Selected:  23927
# Random Publication Selected:  4024
# Random Publication Selected:  20691
# Random Publication Selected:  17584
# Random Publication Selected:  6314
# Random Publication Selected:  22329
# Random Publication Selected:  14205
# Random Publication Selected:  16610
# Random Publication Selected:  14701
# Random Publication Selected:  18651
# Random Publication Selected:  2973
# Random Publication Selected:  12274
# Random Publication Selected:  8532
# Random Publication Selected:  11856
# Random Publication Selected:  16062
# Random Publication Selected:  2139
# Random Publication Selected:  1563
# Random Publication Selected:  9470
# Random Publication Selected:  3014
# Random Publication Selected:  9949
# Random Publication Selected:  5139
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# Your spreadsheet is ready!
# Wiley_Spreadsheet 6.xlsx
# Random Publication Selected:  15304
# Random Publication Selected:  24206
# Random Publication Selected:  8951
# Random Publication Selected:  19311
# Random Publication Selected:  667
# Random Publication Selected:  12464
# Random Publication Selected:  20945
# Random Publication Selected:  5651
# Random Publication Selected:  1539
# Random Publication Selected:  21872
# Random Publication Selected:  14468
# Random Publication Selected:  4854
# Random Publication Selected:  10293
# Random Publication Selected:  10421
# Random Publication Selected:  13793
# Random Publication Selected:  6866
# Random Publication Selected:  1300
# Random Publication Selected:  2710
# Random Publication Selected:  22473
# Random Publication Selected:  15084
# Random Publication Selected:  4734
# Random Publication Selected:  5951
# Random Publication Selected:  20023
# Random Publication Selected:  2713
# Random Publication Selected:  22653
# Random Publication Selected:  351
# Random Publication Selected:  10394
# Random Publication Selected:  6863
# Random Publication Selected:  24820
# Random Publication Selected:  7837
# Random Publication Selected:  1733
# Random Publication Selected:  2403
# Random Publication Selected:  7231
# Random Publication Selected:  16869
# Random Publication Selected:  12568
# Random Publication Selected:  11581
# Random Publication Selected:  1532
# Random Publication Selected:  14860
# Random Publication Selected:  23107
# Random Publication Selected:  15951
# Random Publication Selected:  6318
# Random Publication Selected:  10508
# Random Publication Selected:  5256
# Random Publication Selected:  18768
# Random Publication Selected:  16215
# Random Publication Selected:  9521
# Random Publication Selected:  1208
# Random Publication Selected:  11772
# Random Publication Selected:  12047
# Random Publication Selected:  22937
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# Your spreadsheet is ready!
# Wiley_Spreadsheet 7.xlsx
# Random Publication Selected:  16183
# Random Publication Selected:  13184
# Random Publication Selected:  23607
# Random Publication Selected:  1341
# Random Publication Selected:  11766
# Random Publication Selected:  9708
# Random Publication Selected:  24759
# Random Publication Selected:  16124
# Random Publication Selected:  1459
# Random Publication Selected:  7937
# Random Publication Selected:  20576
# Random Publication Selected:  2780
# Random Publication Selected:  17432
# Random Publication Selected:  10774
# Random Publication Selected:  16213
# Random Publication Selected:  22367
# Random Publication Selected:  17704
# Random Publication Selected:  12216
# Random Publication Selected:  23987
# Random Publication Selected:  15194
# Random Publication Selected:  8527
# Random Publication Selected:  14332
# Random Publication Selected:  18212
# Random Publication Selected:  15561
# Random Publication Selected:  7562
# Random Publication Selected:  20916
# Random Publication Selected:  16093
# Random Publication Selected:  12087
# Random Publication Selected:  19031
# Random Publication Selected:  938
# Random Publication Selected:  21559
# Random Publication Selected:  2394
# Random Publication Selected:  7445
# Random Publication Selected:  549
# Random Publication Selected:  16659
# Random Publication Selected:  22822
# Random Publication Selected:  24377
# Random Publication Selected:  7508
# Random Publication Selected:  21573
# Random Publication Selected:  21191
# Random Publication Selected:  4672
# Random Publication Selected:  538
# Random Publication Selected:  6221
# Random Publication Selected:  19888
# Random Publication Selected:  4996
# Random Publication Selected:  11955
# Random Publication Selected:  22107
# Random Publication Selected:  10463
# Random Publication Selected:  17906
# Random Publication Selected:  11684
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# Your spreadsheet is ready!
# Wiley_Spreadsheet 8.xlsx
# Random Publication Selected:  14405
# Random Publication Selected:  11038
# Random Publication Selected:  3895
# Random Publication Selected:  14200
# Random Publication Selected:  4769
# Random Publication Selected:  22795
# Random Publication Selected:  24516
# Random Publication Selected:  4439
# Random Publication Selected:  9677
# Random Publication Selected:  6771
# Random Publication Selected:  15670
# Random Publication Selected:  3585
# Random Publication Selected:  8060
# Random Publication Selected:  10943
# Random Publication Selected:  7902
# Random Publication Selected:  10101
# Random Publication Selected:  21489
# Random Publication Selected:  6128
# Random Publication Selected:  4083
# Random Publication Selected:  23880
# Random Publication Selected:  16258
# Random Publication Selected:  2444
# Random Publication Selected:  15352
# Random Publication Selected:  6693
# Random Publication Selected:  13179
# Random Publication Selected:  17763
# Random Publication Selected:  18694
# Random Publication Selected:  11574
# Random Publication Selected:  19533
# Random Publication Selected:  18555
# Random Publication Selected:  9911
# Random Publication Selected:  1338
# Random Publication Selected:  9853
# Random Publication Selected:  17141
# Random Publication Selected:  22168
# Random Publication Selected:  13024
# Random Publication Selected:  23593
# Random Publication Selected:  13137
# Random Publication Selected:  17922
# Random Publication Selected:  14939
# Random Publication Selected:  18205
# Random Publication Selected:  22686
# Random Publication Selected:  21238
# Random Publication Selected:  12359
# Random Publication Selected:  16562
# Random Publication Selected:  15832
# Random Publication Selected:  18784
# Random Publication Selected:  23616
# Random Publication Selected:  2170
# Random Publication Selected:  645
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# Your spreadsheet is ready!
# Wiley_Spreadsheet 9.xlsx
# Random Publication Selected:  4920
# Random Publication Selected:  5341
# Random Publication Selected:  5029
# Random Publication Selected:  4221
# Random Publication Selected:  272
# Random Publication Selected:  17938
# Random Publication Selected:  10250
# Random Publication Selected:  20473
# Random Publication Selected:  24645
# Random Publication Selected:  9774
# Random Publication Selected:  6717
# Random Publication Selected:  2396
# Random Publication Selected:  23716
# Random Publication Selected:  17325
# Random Publication Selected:  10258
# Random Publication Selected:  20663
# Random Publication Selected:  3759
# Random Publication Selected:  10292
# Random Publication Selected:  17234
# Random Publication Selected:  24148
# Random Publication Selected:  16086
# Random Publication Selected:  16621
# Random Publication Selected:  16937
# Random Publication Selected:  225
# Random Publication Selected:  19133
# Random Publication Selected:  19228
# Random Publication Selected:  6060
# Random Publication Selected:  13448
# Random Publication Selected:  14684
# Random Publication Selected:  13822
# Random Publication Selected:  9537
# Random Publication Selected:  17849
# Random Publication Selected:  11352
# Random Publication Selected:  1753
# Random Publication Selected:  14513
# Random Publication Selected:  12120
# Random Publication Selected:  8873
# Random Publication Selected:  18267
# Random Publication Selected:  13319
# Random Publication Selected:  2792
# Random Publication Selected:  3884
# Random Publication Selected:  9832
# Random Publication Selected:  24477
# Random Publication Selected:  11031
# Random Publication Selected:  13069
# Random Publication Selected:  14488
# Random Publication Selected:  5461
# Random Publication Selected:  15724
# Random Publication Selected:  5061
# Random Publication Selected:  142
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# On dataframe  1
# On dataframe  2
# On dataframe  3
# On dataframe  4
# On dataframe  5
# On dataframe  6
# On dataframe  7
# On dataframe  8
# On dataframe  9
# On dataframe  10
# Your spreadsheet is ready!
